# %%
import pandas
import matplotlib
from bokeh.plotting import figure, output_notebook, show

# %%
# %load_ext google.cloud.bigquery
# %matplotlib inline

# %%
import os

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/home/mforde/google-creds/creds.json'
print('creds path: {}'.format(os.environ.get('GOOGLE_APPLICATION_CREDENTIALS')))
# Out:
# creds path: /home/mforde/google-creds/creds.json

# %%
# %%bigquery
# SELECT
#     *
# FROM `bigquery-public-data.ncaa_basketball.mascots`
# LIMIT 5
# Out:
#                                      id         market              name  \
# 0  2959bd24-7007-41ae-a3a3-abdf26888cfc          Tulsa  Golden Hurricane
# 1  ad4bc983-8d2e-4e6f-a8f9-80840a786c64  Arizona State        Sun Devils
# 2  f2d01b77-0f5d-4574-9e49-2a3eaf822e44         Drexel           Dragons
# 3  b47d10b8-a2a5-47df-a2f9-7bd0b9d51beb        Bradley            Braves
# 4  0113eea0-c943-4fff-9780-ae0fb099e7ef       Canisius   Golden Griffins
#
#       mascot            mascot_name mascot_common_name tax_subspecies  \
# 0  Hurricane           Captain Cane               None           None
# 1      Devil                 Sparky               None           None
# 2     Dragon  Mario the Magnificent               None           None
# 3   Gargoyle                Kaboom!               None           None
# 4    Griffin                  Petey               None           None
#
#   tax_species tax_genus tax_family tax_order tax_class tax_phylum tax_kingdom  \
# ...

# %%
mascots["mascot"]
# Out:
# 0    Hurricane
# 1        Devil
# 2       Dragon
# 3     Gargoyle
# 4      Griffin
# Name: mascot, dtype: object

# %%
mascots.groupby('mascot').count().head()
# Out:
#            id  market  name  mascot_name  mascot_common_name  tax_subspecies  \
# mascot
# Devil       1       1     1            1                   0               0
# Dragon      1       1     1            1                   0               0
# Gargoyle    1       1     1            1                   0               0
# Griffin     1       1     1            1                   0               0
# Hurricane   1       1     1            1                   0               0
#
#            tax_species  tax_genus  tax_family  tax_order  tax_class  \
# mascot
# Devil                0          0           0          0          0
# Dragon               0          0           0          0          0
# Gargoyle             0          0           0          0          0
# Griffin              0          0           0          0          0
# Hurricane            0          0           0          0          0
#
#            tax_phylum  tax_kingdom  tax_domain  non_tax_type
# mascot
# ...

# %%
from bokeh.plotting import figure

output_notebook()

x_range = mascots["mascot"]

counts = mascots.groupby('mascot')
y_range = []
for x in x_range:
    y_range.add(mascots.groupby("mascot"))

p = figure(x_range=mascots["mascot"])

p.vbar(x=mascots["mascot"], top=[1,2,3,4,5], width=1)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1035">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="531f6792-19aa-4969-9b11-95b34a186bd8" data-root-id="1036"></div>
