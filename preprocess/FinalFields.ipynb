# %%
import pandas as pd

# %%
allData = pd.read_csv("../data/pbp_subset_ordered.csv")

# %%
allData
# Out:
#                                       game_id game_clock  elapsed_time_sec  \
# 0        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      20:00                 0
# 1        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      19:39                21
# 2        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      19:37                23
# 3        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      19:22                38
# 4        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      19:22                38
# 5        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      19:22                38
# 6        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      19:22                38
# 7        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      19:00                60
# 8        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      18:58                62
# 9        000872e5-f02a-4b64-ac73-b6b1a7ad10ec      18:31                89
# 10       000872e5-f02a-4b64-ac73-b6b1a7ad10ec      18:31                89
# ...

# %%
subset = allData.drop('game_clock', 1)

# %%
subset
# Out:
#                                       game_id  elapsed_time_sec team_basket  \
# 0        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                 0       right
# 1        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                21       right
# 2        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                23        left
# 3        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                38        left
# 4        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                38       right
# 5        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                38       right
# 6        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                38        left
# 7        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                60       right
# 8        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                62       right
# 9        000872e5-f02a-4b64-ac73-b6b1a7ad10ec                89        left
# 10       000872e5-f02a-4b64-ac73-b6b1a7ad10ec                89        left
# ...

# %%
subset.to_csv("../data/pbp_final.csv")
