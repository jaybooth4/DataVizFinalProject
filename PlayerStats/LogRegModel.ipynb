# %%
# This file will take in data from PreProcess.py (X=all player data, y=labels (NBA or not))
# and create a logistic regression modelfrom it.

# Outputs are ??

# # Properties to tweak:
#     Class weighting!
#     unless specified to nothing, make the classifier use “balanced” mode which 
#     uses the values of y to automatically adjust weights inversely proportional 
#     to class frequencies in the input data 

weight = 'balanced'

# %%
# %store -r X
# %store -r y

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn import metrics
import statsmodels.api as sm

# %%
#do logistic regression so we can see p values of column variables
logit_model=sm.Logit(y,X)
result=logit_model.fit()
#print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.148246
#          Iterations 8

# %%
#result.pvalues
#result.pvalues[0]
#X.columns[0]

# %%
#remove variables with a p value greater than 0.05
droplist = []
for idx,pval in enumerate(result.pvalues):
    if pval >= 0.05:
        print(X.columns[idx], idx, pval )
        droplist.append(X.columns[idx])
print(droplist)
X=X.drop(columns=droplist)
# Out:
# avg_thrp_pct 4 0.9906111030406739
# avg_twop_pct 5 0.17827726955652168
# avg_off_rebnd 7 0.7458383388107672
# avg_tech_fouls 10 0.9409931608065978
# ['avg_thrp_pct', 'avg_twop_pct', 'avg_off_rebnd', 'avg_tech_fouls']

# %%
X = X.drop(columns=['jersey_num'])
X
# Out:
#          height    weight  avg_points  avg_twop_pct  avg_off_rebnd  \
# 40     0.000000  0.000000    0.000000      0.000000       0.000000
# 64     0.000000  0.000000    0.000000      0.000000       0.000000
# 77     0.000000  0.000000    0.104371      0.300000       0.100446
# 92     0.000000  0.000000    0.071755      0.189286       0.080357
# 94     0.000000  0.000000    0.082801      0.414467       0.187500
# 96     0.119374  0.513889    0.000000      0.000000       0.015625
# 97     0.119374  0.444444    0.009132      0.000588       0.011719
# 98     0.121331  0.388889    0.000000      0.000000       0.000000
# 99     0.121331  0.458333    0.000000      0.000000       0.000000
# 100    0.123288  0.416667    0.028588      0.043478       0.016304
# 101    0.125245  0.555556    0.007306      0.000000       0.018750
# 102    0.127202  0.416667    0.522012      0.245528       0.070134
# 104    0.129159  0.433333    0.000000      0.000000       0.000000
# 105    0.129159  0.402778    0.000000      0.000000       0.000000
# 106    0.129159  0.411111    0.056824      0.001667       0.000000
# 107    0.129159  0.430556    0.157902      0.297871       0.024194
# 108    0.129159  0.444444    0.016960      0.000000       0.006696
# 109    0.129159  0.416667    0.253425      0.038243       0.093750
# 110    0.131115  0.486111    0.000000      0.000000       0.000000
# 111    0.131115  0.444444    0.350457      0.427250       0.017578
# 112    0.131115  0.416667    0.009703      0.000000       0.002930
# 113    0.131115  0.444444    0.626170      0.152399       0.077652
# 114    0.131115  0.388889    0.051142      0.164175       0.054545
# 115    0.131115  0.444444    0.004981      0.000000       0.000000
# 116    0.131115  0.416667    0.683437      0.423460       0.105682
# 117    0.131115  0.402778    0.010194      0.023488       0.000000
# 118    0.131115  0.444444    0.022674      0.000862       0.012931
# 119    0.131115  0.463889    0.070540      0.189655       0.032328
# 120    0.131115  0.416667    0.246237      0.426357       0.069444
# 121    0.131115  0.513889    0.005479      0.000000       0.000000
# ...         ...       ...         ...           ...            ...
# 12785  0.166341  0.750000    0.185910      0.163844       0.160714
# 12786  0.166341  0.708333    0.035351      0.117187       0.054435
# ...            ...             ...                 ...              ...
# 12785     0.008222        0.043478                 0.0              1.0
# 12786     0.011139        0.000000                 0.0              0.0
# 12789     0.028334        0.000000                 0.0              1.0
# 12790     0.123763        0.000000                 0.0              0.0
# 12791     0.017336        0.000000                 0.0              1.0
# 12792     0.027407        0.000000                 0.0              1.0
# 12795     0.020598        0.000000                 0.0              1.0
# 12797     0.024770        0.000000                 0.0              1.0
# 12801     0.018793        0.000000                 0.0              1.0
# 12803     0.013328        0.000000                 0.0              1.0
# 12808     0.000000        0.000000                 0.0              1.0
# 12810     0.057554        0.000000                 0.0              1.0
# 12811     0.000000        0.000000                 0.0              1.0
# 12812     0.000000        0.000000                 0.0              1.0
# 12813     0.059298        0.000000                 0.0              1.0
# 12816     0.011511        0.000000                 0.0              1.0
# 12817     0.017834        0.043478                 0.0              1.0
# 12819     0.024792        0.086957                 0.5              1.0
# 12820     0.046695        0.043478                 0.0              1.0
# 12822     0.000000        0.000000                 0.0              1.0
# 12823     0.000000        0.000000                 0.0              1.0
# 12824     0.008031        0.000000                 0.0              1.0
# 12825     0.000000        0.000000                 0.0              1.0
# 12826     0.057962        0.043478                 0.5              1.0
# 12827     0.043165        0.043478                 0.0              1.0
# 12828     0.000000        0.000000                 0.0              1.0
# 12833     0.002677        0.000000                 0.0              1.0
# 12836     0.000000        0.000000                 0.0              1.0
# 12837     0.038369        0.000000                 0.5              1.0
# 12840     0.000000        0.000000                 0.0              0.0
#
#        position_Guard
# 40                1.0
# 64                1.0
# 77                1.0
# 92                0.0
# 94                1.0
# 96                1.0
# 97                1.0
# 98                1.0
# 99                1.0
# 100               1.0
# 101               1.0
# 102               1.0
# 104               1.0
# 105               1.0
# 106               1.0
# 107               1.0
# 108               1.0
# 109               1.0
# 110               1.0
# 111               1.0
# 112               1.0
# 113               1.0
# 114               1.0
# 115               1.0
# 116               1.0
# 117               1.0
# 118               1.0
# 119               1.0
# 120               1.0
# 121               1.0
# ...               ...
# 12785             0.0
# 12786             0.0
# 12789             0.0
# 12790             0.0
# 12791             0.0
# 12792             0.0
# 12795             0.0
# 12797             0.0
# 12801             0.0
# 12803             0.0
# 12808             0.0
# 12810             0.0
# 12811             0.0
# 12812             0.0
# 12813             0.0
# 12816             0.0
# 12817             0.0
# 12819             0.0
# 12820             0.0
# 12822             0.0
# 12823             0.0
# 12824             0.0
# 12825             0.0
# 12826             0.0
# 12827             0.0
# 12828             0.0
# 12833             0.0
# 12836             0.0
# 12837             0.0
# 12840             1.0
#
# [11409 rows x 10 columns]

# %%
#class_weight=weight
#
# Actually train the classifier now that we have the good data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)
logreg = LogisticRegression(class_weight=weight)
logreg.fit(X_train, y_train.values.ravel())
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='warn', n_jobs=None, penalty='l2', random_state=None,
#           solver='warn', tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.5f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.74262

# %%
#y_score = logreg.predict_proba(X_test) # returns probs that data points belong to neg and pos classes
#only keep pos probs actually
y_score = logreg.predict_proba(X_test)[:,1]

# %%
# %store X_test
# %store y_test
# %store y_pred
# %store y_score
# del X_test
# del y_test
# del y_pred
# Out:
# Stored 'X_test' (DataFrame)
# Stored 'y_test' (DataFrame)
# Stored 'y_pred' (ndarray)
# Stored 'y_score' (ndarray)
